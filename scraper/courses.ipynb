# %% [markdown]
# ## Courses Scraper

# %%
import requests
import pandas as pd
import os

# %%
# # Example JSON ouptut
# example_data = requests.get("https://websearch.mq.edu.au/s/search.json?collection=mq-edu-au-push-courses&profile=domestic&f.Study+level|studyLevel=Undergraduate&f.Study+type|courseType=Course&f.Study+type|courseType=Majors+and+Specialisations&query=!padrenull&start_rank=1")
# example_data.json()['response']['resultPacket']['results']

# %%
def courses_scraper(api_url, output_csv):
    data_list = []
    page = 1
    per_page = 10  # Adjust this based on the actual API response

    while True:
        params = {
            'collection': 'mq-edu-au-push-courses',
            'profile': 'domestic',
            'f.Study+level|studyLevel': 'Undergraduate',
            'f.Study+type|courseType': ['Course', 'Majors+and+Specialisations'],
            'query': '!padrenull',
            'start_rank': (page - 1) * per_page + 1
        }

        response = requests.get(api_url, params=params)
        print("This is response: ", response)

        if response.status_code == 200:
            # Parse the JSON response
            api_data = response.json()

            # Extract relevant information from the API response
            n = api_data['response']['resultPacket']['results']
            if not n:
                break  # No more data available
            for i in n:
                # Not every course has a course code
                course_code = i['listMetadata'].get('courseCode', ['N/A'])[0]
                # Append the extracted data to the list
                data_list.append({
                    'course_name': i['listMetadata']['courseName'][0],
                    'course_type': i['listMetadata']['courseType'][0],
                    'course_code': course_code,
                    'course_url': i['liveUrl']
                })
            # Move to the next page
            page += 1
        else:
            print(f"Error: {response.status_code}")
            break

    # Convert the list of dictionaries to a DataFrame
    print(data_list)
    df = pd.DataFrame(data_list)

    # Create the 'data' folder if it doesn't exist
    data_folder = '../data'  # Use '../data' to go up one level
    os.makedirs(data_folder, exist_ok=True)

    # Save DataFrame to CSV in the 'data' folder
    output_path = os.path.join(data_folder, output_csv)
    df.to_csv(output_path, index=False)
    print(f"Data successfully scraped and stored in {output_path}")

# Example usage
api_url = "https://websearch.mq.edu.au/s/search.json"
output_csv = "courses.csv"
courses_scraper(api_url, output_csv)
# Out:
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# This is response:  <Response [200]>
# [{'course_name': 'Master of Data Science', 'course_type': 'Course', 'course_code': 'C000082', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/master-of-data-science'}, {'course_name': 'Bachelor of Laws', 'course_type': 'Course', 'course_code': 'C000132', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/bachelor-of-laws'}, {'course_name': 'Master of Laws', 'course_type': 'Course', 'course_code': 'C000184', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/master-of-laws'}, {'course_name': 'Master of Planning', 'course_type': 'Course', 'course_code': 'C000033', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/master-of-planning'}, {'course_name': 'Major in Data Science', 'course_type': 'Majors and Specialisations', 'course_code': 'N/A', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/major/data-science'}, {'course_name': 'Bachelor of Science', 'course_type': 'Course', 'course_code': 'C000352', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/bachelor-of-science'}, {'course_name': 'Bachelor of Music', 'course_type': 'Course', 'course_code': 'C000091', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/bachelor-of-music'}, {'course_name': 'Major in Biology', 'course_type': 'Majors and Specialisations', 'course_code': 'N/A', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/major/biology'}, {'course_name': 'Bachelor of Business', 'course_type': 'Course', 'course_code': 'C000389', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/bachelor-of-business'}, {'course_name': 'Major in English', 'course_type': 'Majors and Specialisations', 'course_code': 'N/A', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/major/english'}, {'course_name': 'Specialisation in Finance', 'course_type': 'Majors and Specialisations', 'course_code': 'N/A', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/specialisation/finance'}, {'course_name': 'Specialisation in FinTech', 'course_type': 'Majors and Specialisations', 'course_code': 'N/A', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/specialisation/fintech'}, {'course_name': 'Bachelor of Security Studies', 'course_type': 'Course', 'course_code': 'C000015', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/bachelor-of-security-studies'}, {'course_name': 'Master of Banking and Finance', 'course_type': 'Course', 'course_code': 'C000101', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/master-of-banking-and-finance'}, {'course_name': 'Major in Radio, Podcasting, and Audio Media', 'course_type': 'Majors and Specialisations', 'course_code': 'N/A', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/major/radio-podcasting-and-audio-media'}, {'course_name': 'Graduate Diploma of Applied Finance', 'course_type': 'Course', 'course_code': 'C000152', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/graduate-diploma-of-applied-finance'}, {'course_name': 'Major in Neuroscience', 'course_type': 'Majors and Specialisations', 'course_code': 'N/A', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/major/neuroscience'}, {'course_name': 'Master of Engineering Management', 'course_type': 'Course', 'course_code': 'C000177', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/master-of-engineering-management'}, {'course_name': 'Graduate Certificate of Finance', 'course_type': 'Course', 'course_code': 'C000145', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/graduate-certificate-of-finance'}, {'course_name': 'Bachelor of Environment and Bachelor of Laws', 'course_type': 'Double Degree', 'course_code': 'D000047', 'course_url': 'https://www.mq.edu.au/study/find-a-course/courses/bachelor-of-environment-and-bachelor-of-laws'}, {'course_name': 'Bachelor of Arts and Bachelor of Education (Primary)', 'course_type': 'Course', 'course_code': 'D00000 ...
# Data successfully scraped and stored in data\courses.csv

# %% [markdown]
# ## Units of Course Scraper

# %%
import requests

url = "https://www.mq.edu.au/study/page-data/find-a-course/courses/bachelor-of-laws/page-data.json"
url2 = "https://www.mq.edu.au/study/page-data/find-a-course/courses/bachelor-of-information-technology/page-data.json"

# Make the request
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # Extract and print relevant information
    page_data = data.get("result", {}).get("data", {}).get("page", {})

    if page_data:
        print("Title:", page_data.get("title", ""))
        print("Description:", page_data.get("description", ""))
        # Add more fields as needed

    else:
        print("No data found in the response.")
else:
    print(f"Error: {response.status_code}")
# Out:
# No data found in the response.

# %%
data['result']['data']['current']['fields']['json']
# Out:
# '{"school":{"value":"Faculty of Arts","key":"name"},"published_in_handbook":{"label":"Yes","value":"1"},"search_title":"Bachelor of Laws","code":"C000132","abbreviated_name_and_major":"","implementation_year":"2024","credit_points":"320","accrediting_bodies":[],"enrolment_patterns":["Part Time","Full Time"],"content_type":"Course","study_level":"Undergraduate","academic_org":{"value":"","key":"name"},"status":{"label":"Approved","value":"Active"},"title":"Bachelor of Laws","abbreviated_name":"","aqf_level":{"label":"Level 7","value":"level_7"},"type":{"label":"Specialist Bachelor Degree","value":"specialist_bachelor_degree"},"description":null,"version":"2","course_code":"C000132","version_name":"2024.02","atar":"96","award_titles":"","cricos_code":"080288E","learning_and_teaching_methods":"<p>The Bachelor of Laws uses both lectures and small group tutorials. Tutorials emphasise participation and the development of verbal communication skills.</p>\\n<p><br /><br /><br /><br /></p>","support_for_learning":"","recommended_studies":"","uac_codes":"300160","selection_rank":"90","assumed_knowledge":"","overview_and_aims_of_the_course":"<p>The Bachelor of Laws is a four year accredited professional course that meets the academic requirements for admission to practice as a lawyer in NSW. It has been benchmarked with undergraduate law degrees from around Australia. The Bachelor of Laws continues to emphasise law in its social, cultural, economic and environmental context and has been developed with a particular emphasis on professional skills. Undergraduate law is traditionally offered over 4 years and includes a suite of compulsory law units for accreditation purposes.\xa0Elective subjects enable students to tailor the course to their particular interests and develop specific skillsets.</p>","ielts_writing_score":"6.5","ielts_listening_score":"6.5","ielts_speaking_score":"6.5","course_duration_in_years":{"label":"Full time: 4 years"},"admission_requirements":"","ielts_reading_score":"6.5","accreditation_text_for_ahegs":"The Macquarie Bachelor of Laws is accredited with professional bodies regulating the admission of law graduates to legal practice. The Bachelor of Laws provides the appropriate qualification for admission to practice as a lawyer throughout Australia. In addition to completing a law course at an accredited institution, the profession requires all law graduates to complete a period of Practical Legal Training including further study and supervised experience in a legal practice. ","ielts_overall_score":"7","level2_org_unit_data":[],"offering":[{"student_types":["International students studying within Australia on a visa","Domestic students"],"language_of_instruction":{"label":"English","value":"en"},"offered":"false","location":"North Ryde","clarification_to_appear_in_handbook":"","academic_item":{"value":"C000132","key":"code"},"mode":{"value":"","key":"description"},"start_date":"","ext_id":"","linking_id":"75708531db527f004ed764d31496192f","name":"C000132","order":"","end_date":"","year":"","publish":"true","display_name":"Session 1-North Ryde","admission_calendar":"Session 1","attendance_type":[],"comments":"","entry_point":"false","status":{"label":null,"value":null}},{"student_types":["International students studying within Australia on a visa","Domestic students"],"language_of_instruction":{"label":"English","value":"en"},"offered":"false","location":"North Ryde","clarification_to_appear_in_handbook":"","academic_item":{"value":"C000132","key":"code"},"mode":{"value":"","key":"description"},"start_date":"","ext_id":"","linking_id":"39708531db527f004ed764d314961930","name":"C000132","order":"","end_date":"","year":"","publish":"true","display_name":"Session 2-North Ryde","admission_calendar":"Session 2","attendance_type":[],"comments":"","entry_point":"false","status":{"label":null,"value":null}}],"study_modes":[],"course_availabilities":[],"articulations":[{"articulation_conditions":"<p>Admission to Honours will  ...

# %%
# convert string to json
import json
converted = json.loads(data['result']['data']['current']['fields']['json'])

# %%
converted
# Out:
# {'school': {'value': 'Faculty of Arts', 'key': 'name'},
#  'published_in_handbook': {'label': 'Yes', 'value': '1'},
#  'search_title': 'Bachelor of Laws',
#  'code': 'C000132',
#  'abbreviated_name_and_major': '',
#  'implementation_year': '2024',
#  'credit_points': '320',
#  'accrediting_bodies': [],
#  'enrolment_patterns': ['Part Time', 'Full Time'],
#  'content_type': 'Course',
#  'study_level': 'Undergraduate',
#  'academic_org': {'value': '', 'key': 'name'},
#  'status': {'label': 'Approved', 'value': 'Active'},
#  'title': 'Bachelor of Laws',
#  'abbreviated_name': '',
#  'aqf_level': {'label': 'Level 7', 'value': 'level_7'},
#  'type': {'label': 'Specialist Bachelor Degree',
#   'value': 'specialist_bachelor_degree'},
#  'description': None,
#  'version': '2',
#  'course_code': 'C000132',
#  'version_name': '2024.02',
#  'atar': '96',
#  'award_titles': '',
#  'cricos_code': '080288E',
#  'learning_and_teaching_methods': '<p>The Bachelor of Laws uses both lectures and small group tutorials. Tutorials emphasise participation and the development of verbal communication skills.</p>\n<p><br /><br /><br /><br /></p>',
#  'support_for_learning': '',
#  'recommended_studies': '',
#  'uac_codes': '300160',
#  'selection_rank': '90',
#  'assumed_knowledge': '',
#  'overview_and_aims_of_the_course': '<p>The Bachelor of Laws is a four year accredited professional course that meets the academic requirements for admission to practice as a lawyer in NSW. It has been benchmarked with undergraduate law degrees from around Australia. The Bachelor of Laws continues to emphasise law in its social, cultural, economic and environmental context and has been developed with a particular emphasis on professional skills. Undergraduate law is traditionally offered over 4 years and includes a suite of compulsory law units for accreditation purposes.\xa0Elective subjects enable students to tailor the course to their particular interests and develop specific skillsets.</p>',
#  'ielts_writing_score': '6.5',
#  'ielts_listening_score': '6.5',
#  'ielts_speaking_score': '6.5',
#  'course_duration_in_years': {'label': 'Full time: 4 years'},
#  'admission_requirements': '',
#  'ielts_reading_score': '6.5',
#  'accreditation_text_for_ahegs': 'The Macquarie Bachelor of Laws is accredited with professional bodies regulating the admission of law graduates to legal practice. The Bachelor of Laws provides the appropriate qualification for admission to practice as a lawyer throughout Australia. In addition to completing a law course at an accredited institution, the profession requires all law graduates to complete a period of Practical Legal Training including further study and supervised experience in a legal practice. ',
#  'ielts_overall_score': '7',
#  'level2_org_unit_data': [],
#  'offering': [{'student_types': ['International students studying within Australia on a visa',
#     'Domestic students'],
#    'language_of_instruction': {'label': 'English', 'value': 'en'},
#    'offered': 'false',
#    'location': 'North Ryde',
#    'clarification_to_appear_in_handbook': '',
#    'academic_item': {'value': 'C000132', 'key': 'code'},
#    'mode': {'value': '', 'key': 'description'},
#    'start_date': '',
#    'ext_id': '',
#    'linking_id': '75708531db527f004ed764d31496192f',
#    'name': 'C000132',
#    'order': '',
#    'end_date': '',
#    'year': '',
#    'publish': 'true',
#    'display_name': 'Session 1-North Ryde',
#    'admission_calendar': 'Session 1',
#    'attendance_type': [],
#    'comments': '',
#    'entry_point': 'false',
#    'status': {'label': None, 'value': None}},
#   {'student_types': ['International students studying within Australia on a visa',
#     'Domestic students'],
#    'language_of_instruction': {'label': 'English', 'value': 'en'},
#    'offered': 'false',
#    'location': 'North Ryde',
#    'clarification_to_appear_in_handbook': '',
#    'academic_item': {'value': 'C000132', 'key': 'code'},
#    'mode': {'value': '', 'key': 'description'},
#    'start_date': '',
#    'ext_id': '',
#    'linking_id': '39708531db527f004ed764d314961930',
#    'name': 'C000132',
#    'order': '',
#    'end_date': '',
#    'year': '',
#    'publish': 'true',
#    'display_name': 'Session 2-North Ryde',
#    'admission_calendar': 'Session 2',
#    'attendance_type': [],
#    'comments': '',
#    'entry_point': 'false',
#    'status': {'label': None, 'value': None}}],
#  'study_modes': [],
#  'course_availabilities': [],
#  'articulations': [{'articulation_conditions': "<p>Admission to Honours will be by direct internal application for a course transfer. Law students will be eligible for automatic transfer to the Bachelor of Laws (Honours) program if they meet the following criteria:</p>\n<ol>\n<li>Successful completion of a minimum of 160 CP in LAWS units, and</li>\n<li>Have a WAM in their graded LAWS units of 75.00 or above.</li>\n</ol>\n<p><strong>Award of first class honours</strong><br />Students who have completed all of the requirements of their Bachelor of Law (Honours) will graduate with first class honours if they have attained a Law WAM of 75 or above.</p>\n<p><strong>Award of second class honours</strong><br />Students who have completed all of the requirements of their Bachelor of Laws (Honours) will be eligible for second class honours if they have attained a WAM of less than 75. <br /><br />Calculation of WAM<br />A student's LAWS WAM is calculated as follows:<br />1. Multiply the unit mark for each first attempt of a graded LAWS unit by the value of that unit in terms of credit points;<br />2. Sum the resulting values (weighted marks);<br />3. Divide the sum of the weighted marks by the total value (in terms of credit points) of all graded LAWS units attempted by the student.</p>\n<p>Students who do not meet the criteria for either First or Second class Honours will be eligible for the Bachelor of Laws, provided they meet all other criteria for that award</p>",
#    'course': 'Bachelor of Laws (Honours) C000195 Active',
#    'details': '',
#    'credit_transfer_arrangements': {'label': 'Full credit',
#     'value': 'full_credit'}}],
#  'curriculum_structure': [{'ai_to_cs_cl_id': 'dc9ff57b9776fd9049533c4ef053af9e',
#    'curriculum_structure': {'value': '', 'key': 'version_code'},
#    'source': {'value': '', 'key': ''},
#    'effective_date': '',
#    'credit_points': '320',
#    'structure_cl_id': 'fc8002fb9776fd9049533c4ef053af72',
#    'parent_table': 'x_f5sl_cl_courses',
#    'name': 'Structure',
#    'parent_id': {'value': 'Course: C000132',
#     'key': 'code',
#     'type': 'x_f5sl_cl_courses'},
#    'container': [{'child_table': '',
#      'footnote': '',
#      'map_type': '',
#      'parent_table': 'x_f5sl_cl_curriculum_structure',
#      'parent_connector': {'label': 'AND', 'value': 'AND'},
#      'description': 'You can use your flexible zone to enrol in any Undergraduate unit for which you meet the requisites. You may also use your flexible zone to complete a major or a minor(s).',
#      'credit_points': '80',
#      'horizontal_grouping': {'label': None, 'value': None},
#      'title': 'Flexible Zone',
#      'vertical_grouping': {'label': 'FLEXIBLE', 'value': 'flexible'},
#      'credit_points_max': '',
#      'parent_record': {'value': 'Curriculum Structure: ',
#       'key': 'version_code',
#       'type': 'x_f5sl_cl_curriculum_structure'},
#      'preface': '',
#      'dynamic_query': '',
#      'child_record': {'value': '', 'key': '', 'type': None},
#      'relationship': [],
#      'dynamic_relationship': [],
#      'container': [],
#      'order': '100'},
#     {'child_table': '',
#      'footnote': '',
#      'map_type': '',
#      'parent_table': 'x_f5sl_cl_curriculum_structure',
#      'parent_connector': {'label': 'AND', 'value': 'AND'},
#      'description': '',
#      'credit_points': '240',
#      'horizontal_grouping': {'label': None, 'value': None},
#      'title': 'Core Zone',
#      'vertical_grouping': {'label': 'CORE', 'value': 'core'},
#      'credit_points_max': '',
#      'parent_record': {'value': 'Curriculum Structure: ',
#       'key': 'version_code',
#       'type': 'x_f5sl_cl_curriculum_structure'},
#      'preface': '',
#      'dynamic_query': '',
#      'child_record': {'value': '', 'key': '', 'type': None},
#      'relationship': [],
#      'dynamic_relationship': [],
#      'container': [{'child_table': '',
#        'footnote': '',
#        'map_type': '',
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'description': 'Complete 10 credit points from the following PACE options.',
#        'credit_points': '10',
#        'horizontal_grouping': {'label': None, 'value': None},
#        'title': 'Elective units',
#        'vertical_grouping': {'label': 'ELECTIVE', 'value': 'elective'},
#        'credit_points_max': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Core Zone',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'preface': '',
#        'dynamic_query': '',
#        'child_record': {'value': '', 'key': '', 'type': None},
#        'relationship': [{'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5078',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'PACE: Clinics and Projects',
#          'academic_item_code': 'LAWS5078',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5078',
#          'order': '100'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5051',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'PACE: Individual Placements',
#          'academic_item_code': 'LAWS5051',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5051',
#          'order': '0'}],
#        'dynamic_relationship': [],
#        'container': [],
#        'order': '200'},
#       {'child_table': '',
#        'footnote': '',
#        'map_type': '',
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'description': 'Complete the capstone unit below.',
#        'credit_points': '10',
#        'horizontal_grouping': {'label': None, 'value': None},
#        'title': 'Capstone unit',
#        'vertical_grouping': {'label': 'CAPSTONE', 'value': 'capstone'},
#        'credit_points_max': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Core Zone',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'preface': '',
#        'dynamic_query': '',
#        'child_record': {'value': '', 'key': '', 'type': None},
#        'relationship': [{'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Capstone unit',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5000',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Remedies, Reparations and Resolution in Law',
#          'academic_item_code': 'LAWS5000',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5000',
#          'order': '0'}],
#        'dynamic_relationship': [],
#        'container': [],
#        'order': '100'},
#       {'child_table': '',
#        'footnote': '',
#        'map_type': '',
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'description': 'Complete 80 credit points from the following options.',
#        'credit_points': '80',
#        'horizontal_grouping': {'label': None, 'value': None},
#        'title': 'Elective units',
#        'vertical_grouping': {'label': 'ELECTIVE', 'value': 'elective'},
#        'credit_points_max': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Core Zone',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'preface': '',
#        'dynamic_query': '',
#        'child_record': {'value': '', 'key': '', 'type': None},
#        'relationship': [{'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5056',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Succession',
#          'academic_item_code': 'LAWS5056',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5056',
#          'order': '1800'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5018',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Indigenous Peoples and the Law',
#          'academic_item_code': 'LAWS5018',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5018',
#          'order': '500'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5020',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Family Law',
#          'academic_item_code': 'LAWS5020',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5020',
#          'order': '700'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5065',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Dispute Management and Resolution',
#          'academic_item_code': 'LAWS5065',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5065',
#          'order': '2100'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5030',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Law Moots and Competitions',
#          'academic_item_code': 'LAWS5030',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5030',
#          'order': '1200'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5069',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Energy and Natural Resources Law',
#          'academic_item_code': 'LAWS5069',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5069',
#          'order': '2200'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5087',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Law of Armed Conflict',
#          'academic_item_code': 'LAWS5087',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5087',
#          'order': '2900'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5053',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Taxation',
#          'academic_item_code': 'LAWS5053',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5053',
#          'order': '1700'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5071',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Health Law and Ethics',
#          'academic_item_code': 'LAWS5071',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5071',
#          'order': '2300'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5910',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Research Methodologies in Law',
#          'academic_item_code': 'LAWS5910',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5910',
#          'order': '3400'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5043',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Climate Change Law',
#          'academic_item_code': 'LAWS5043',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5043',
#          'order': '1500'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5036',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Modern Corporate Governance',
#          'academic_item_code': 'LAWS5036',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5036',
#          'order': '1300'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5082',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Insolvency Law',
#          'academic_item_code': 'LAWS5082',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5082',
#          'order': '2600'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5010',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'International Trade Law',
#          'academic_item_code': 'LAWS5010',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5010',
#          'order': '200'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5021',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Foundations of Commercial Law',
#          'academic_item_code': 'LAWS5021',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5021',
#          'order': '800'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5920',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Legal Research Project',
#          'academic_item_code': 'LAWS5920',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5920',
#          'order': '3500'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5080',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Human Rights and Moral Dilemmas',
#          'academic_item_code': 'LAWS5080',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5080',
#          'order': '2500'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5028',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Competition Law',
#          'academic_item_code': 'LAWS5028',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5028',
#          'order': '1000'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5079',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Refugees and Migration',
#          'academic_item_code': 'LAWS5079',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5079',
#          'order': '2400'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5057',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'International Private Law',
#          'academic_item_code': 'LAWS5057',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5057',
#          'order': '1900'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5007',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Employment and Labour Law ',
#          'academic_item_code': 'LAWS5007',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5007',
#          'order': '100'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5302',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'International Law Exchange 2',
#          'academic_item_code': 'LAWS5302',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5302',
#          'order': '3100'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5040',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Environmental Planning Law',
#          'academic_item_code': 'LAWS5040',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5040',
#          'order': '1400'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5084',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Media Law',
#          'academic_item_code': 'LAWS5084',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5084',
#          'order': '2700'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5023',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Intellectual Property Law',
#          'academic_item_code': 'LAWS5023',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5023',
#          'order': '900'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5304',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'International Law Exchange 4',
#          'academic_item_code': 'LAWS5304',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5304',
#          'order': '3300'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5301',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'International Law Exchange 1',
#          'academic_item_code': 'LAWS5301',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5301',
#          'order': '3000'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5086',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Law of the Sea',
#          'academic_item_code': 'LAWS5086',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5086',
#          'order': '2800'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5060',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Environmental Law',
#          'academic_item_code': 'LAWS5060',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5060',
#          'order': '2000'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5005',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Age and the Law ',
#          'academic_item_code': 'LAWS5005',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5005',
#          'order': '0'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5012',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Banking and Finance Law ',
#          'academic_item_code': 'LAWS5012',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5012',
#          'order': '400'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5011',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Discrimination and the Law',
#          'academic_item_code': 'LAWS5011',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5011',
#          'order': '300'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5019',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.02R',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'International Human Rights Law',
#          'academic_item_code': 'LAWS5019',
#          'academic_item_credit_points': '10',
#          'abbreviated_name_and_major': None,
#          'academic_item_url': '/2024/units/LAWS5019',
#          'order': '600'},
#         {'parent_connector': {'label': 'AND', 'value': 'AND'},
#          'credit_points': '',
#          'description': '',
#          'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#           'key': 'title',
#           'type': 'x_f5sl_cl_cs_container'},
#          'owning_structure': {'value': '', 'key': 'version_code'},
#          'child_table': 'x_f5sl_cl_subjects',
#          'vertical_grouping': {'label': None, 'value': None},
#          'child_record': {'value': 'Unit: LAWS5029',
#           'key': 'code',
#           'type': 'x_f5sl_cl_subjects'},
#          'parent_table': 'x_f5sl_cl_cs_container',
#          'abbr_name': '',
#          'academic_item_version_name': '2024.01',
#          'academic_item_type': 'subject',
#          'academic_item_name': 'Law and Technology',
#          'academic_item_code': 'LAWS5029',
#          'academic_item_credit_points': '10',
# ...
#     'published': 'false',
#     'name': 'Top 150 in the world',
#     'type': '',
#     'display_name': 'Top 150 in the world',
#     'theme': 'Law'},
#    {'title': 'Participate in an extensive range of mooting competitions',
#     'other_description': '<p>Take part in mooting competitions organised by the Macquarie University Law Society – make friends and learn professional skills.</p>',
#     'unique_selling_point_type': 'Key Features',
#     'description_ref': '',
#     'keywords': [],
#     'applies_to_all_countries': 'true',
#     'linking_id': '3d92e9eedb1174104a0db1a5f39619a0',
#     'countries': [],
#     'order': '1'}],
#   'further_studies': [{'title': '',
#     'keywords': [],
#     'linking_id': '1cc4ada2db5174104a0db1a5f396194a',
#     'description': '<p>At the heart of our bachelor degrees is focus and flexibility. As such, all our degrees have a core zone and a flexible zone. Your core zone provides your area of study’s focus and consists of the units you’re required to complete. Your flexible zone allows you to follow your passions – gain more depth in your chosen area or explore something different.</p>'}],
#   'applications': [{'instruction': {'value': 'International - Undergraduate - 2024 - Studylink - Generic (International)',
#      'key': 'display_name'},
#     'application_link': '',
#     'keywords': [],
#     'description': None,
#     'linking_id': '0809212adb5174104a0db1a5f39619bd',
#     'student_types': [],
#     'title': '',
#     'applies_to_all_student_types': 'true',
#     'apply_now_url': 'https://admissions.mq.edu.au/index.cfm',
#     'application_method': {'value': 'Studylink', 'key': 'display_name'},
#     'order': '27',
#     'instructions': '<p><strong>Apply online</strong></p>\n\n<p>The quickest way to apply is through our <a href="" rel="nofollow">Online Application Manager</a>.</p>\n\n<p>The Online Application Manager allows you to save your application and come back to it later. You can also track the status of your application.</p>\n\n<p>Please note: If you are currently completing an\xa0<strong>Australian Year 12 secondary school certificate\xa0</strong>(from NSW or interstate, either onshore or offshore), you must apply via the Universities Admissions Centre (UAC). For more information, key dates, and to apply, visit the\xa0<a href="" rel="nofollow">UAC website</a>.</p>\n\n<p><strong>What you need to apply</strong></p>\n\n<p>Your application will require <a href="" rel="nofollow">certified</a> copies of the following documents:</p>\n\n<ul><li>passport</li><li>evidence of <a href="" rel="nofollow">previous academic qualifications</a> and transcripts (including translations if your qualifications are not in English)</li><li>evidence of <a href="" rel="nofollow">English proficiency</a> (where applicable)</li></ul>',
#     'application_notes': None,
#     'published': 'false',
#     'name': 'International - Undergraduate - 2024 - Studylink',
#     'application_type': {'value': 'Generic (International)',
#      'key': 'display_name'},
#     'display_name': 'International - Undergraduate - 2024 - Studylink - Generic (International)',
#     'student_type': {'value': 'Domestic', 'key': 'display_name'},
#     'application_dates': [{'implementation_year': '2024',
#       'published': 'false',
#       'intake': {'value': 'Session 2', 'key': 'name'},
#       'application_start_date': '2023-01-01',
#       'application_information': {'value': 'International - Undergraduate - 2024 - Studylink - Generic (International)',
#        'key': 'display_name'},
#       'order': '',
#       'application_close_date': '2024-07-08'},
#      {'implementation_year': '2024',
#       'published': 'false',
#       'intake': {'value': 'Session 1', 'key': 'name'},
#       'application_start_date': '2023-01-01',
#       'application_information': {'value': 'International - Undergraduate - 2024 - Studylink - Generic (International)',
#        'key': 'display_name'},
#       'order': '',
#       'application_close_date': '2024-02-05'},
#      {'implementation_year': '2024',
#       'published': 'false',
#       'intake': {'value': 'Session 3', 'key': 'name'},
#       'application_start_date': '2023-01-01',
#       'application_information': {'value': 'International - Undergraduate - 2024 - Studylink - Generic (International)',
#        'key': 'display_name'},
#       'order': '',
#       'application_close_date': '2024-11-25'}]},
#    {'instruction': {'value': 'Domestic - Undergraduate - 2024 - UAC (UG) - Generic',
#      'key': 'display_name'},
#     'application_link': '',
#     'keywords': [],
#     'description': None,
#     'linking_id': 'd7b829e6db5174104a0db1a5f39619c3',
#     'student_types': [],
#     'title': '',
#     'applies_to_all_student_types': 'true',
#     'apply_now_url': 'https://www5.uac.edu.au/uacug/',
#     'application_method': {'value': 'Domestic UG', 'key': 'display_name'},
#     'order': '1',
#     'instructions': '<p>Australian or New Zealand citizens, permanent residents of Australia, or holders of Australian permanent resident humanitarian visas who are applying for undergraduate study at Macquarie must apply through the <a href="https://www5.uac.edu.au/uacug/" rel="nofollow">Universities Admissions Centre (UAC)</a>.</p>\n<p>To be considered for this course, you must search (based upon the UAC Code provided above) and include it as one of your course <a href="https://www.mq.edu.au/study/admissions-and-entry/apply/undergraduate/uac" rel="nofollow">preferences</a>.</p>\n<p><strong>What you&#39;ll need to apply</strong></p>\n<p>When submitting your application, it&#39;s important you provide:</p>\n<ul><li>your personal details (including a personal email address; don&#39;t use a school address as it will expire)</li><li>your name as listed on your official ID, otherwise you&#39;ll have problems when you enrol</li><li>details of your studies and qualifications (including completed secondary studies and complete or incomplete certificate, diploma and degree studies)</li><li>evidence of English language proficiency (if required)</li></ul>',
#     'application_notes': None,
#     'published': 'false',
#     'name': 'Domestic - Undergraduate - 2024 - UAC (UG)',
#     'application_type': {'value': 'Generic', 'key': 'display_name'},
#     'display_name': 'Domestic - Undergraduate - 2024 - UAC (UG) - Generic',
#     'student_type': {'value': 'Domestic', 'key': 'display_name'},
#     'application_dates': [{'implementation_year': '2024',
#       'published': 'false',
#       'intake': {'value': 'Session 2', 'key': 'name'},
#       'application_start_date': '2024-04-03',
#       'application_information': {'value': 'Domestic - Undergraduate - 2024 - UAC (UG) - Generic',
#        'key': 'display_name'},
#       'order': '',
#       'application_close_date': '2024-07-08'},
#      {'implementation_year': '2024',
#       'published': 'false',
#       'intake': {'value': 'Session 1', 'key': 'name'},
#       'application_start_date': '2023-04-05',
#       'application_information': {'value': 'Domestic - Undergraduate - 2024 - UAC (UG) - Generic',
#        'key': 'display_name'},
#       'order': '',
#       'application_close_date': '2024-02-05'}]}],
#   'rankings': [],
#   'employments': {'professions': ['Politician',
#     'Public servant',
#     'Barrister or solicitor',
#     'Lobbyist',
#     'Diplomat',
#     'CEO or general manager',
#     'Policy adviser'],
#    'employer_groups': ['Educational institutions',
#     'Regulatory authorities',
#     'Banks and financial institutions',
#     'Public service',
#     'Start-ups',
#     'Media and news outlets',
#     'Legal service providers',
#     'Diplomatic and consular agencies',
#     'Consumer goods manufacturers and retail firms',
#     'NGOs',
#     'Government agencies and departments',
#     'Consulting firms',
#     'Health organisations',
#     'Community legal centres',
#     'Pharmaceutical companies',
#     'Technology and telecommunications companies'],
#    'order': '0',
#    'salary_information': '<p>Job Outlook – an Australian Government initiative – makes it easy to find career information, including the outlook, pay, main tasks, and physical and other demands of careers that interest you.</p>\n<p><a href="https://joboutlook.gov.au/careers/explore-careers" target="_blank" rel="noopener noreferrer nofollow">Explore careers on Job Outlook</a></p>',
#    'linking_id': '3cd4ada2db5174104a0db1a5f3961933',
#    'title': 'Top grad employability',
#    'career_opportunities': '<p>Above national average for graduate employability in law: QILT, Graduate Outcomes Survey 2018–2020.</p>',
#    'marketing_statement1': '<p>So that you’re equipped with the knowledge and skills employers require now and in the future, we design many of our degrees in consultation with a range of industries and sectors. Having such experts involved in creating the fundamentals of your degree provides you with opportunities to contextualise your learning, and gain the latest career insights.</p>',
#    'employability': [{'title': 'In-built internships',
#      'career_opportunities': '<p>Study a degree with built-in practical experiences, and get an invaluable head start in your career.</p>\n<p><a href="https://students.mq.edu.au/careers/looking/internships" target="_blank" rel="noopener noreferrer nofollow">Degrees with internships</a></p>'},
#     {'title': 'Career service',
#      'career_opportunities': '<p>Get help preparing a résumé, identifying job opportunities and connecting with employers.</p>\n<p><a href="https://students.mq.edu.au/careers/career-and-employment-service" target="_blank" rel="noopener noreferrer nofollow">View job opportunities</a></p>'},
#     {'title': 'Top grad employability',
#      'career_opportunities': '<p>Above national average for graduate employability in law: QILT, Graduate Outcomes Survey 2018–2020.</p>'}]},
#   'related_associated_academic_items': [{'mi_assoc_status': {'label': 'Approved',
#      'value': None},
#     'assoc_cl_id': '79a3ccaadbcb6090a4b61f4f049619a6',
#     'assoc_code': 'C000009',
#     'credit_points': '240',
#     'assoc_title': 'Bachelor of Psychology',
#     'short_title': 'C000009 - Bachelor of Psychology'},
#    {'mi_assoc_status': {'label': 'Approved', 'value': None},
#     'assoc_cl_id': '6a93d422db0b64904a0db1a5f396194e',
#     'assoc_code': 'C000130',
#     'credit_points': '240',
#     'assoc_title': 'Bachelor of Commerce',
#     'short_title': 'C000130 - Bachelor of Commerce'},
#    {'mi_assoc_status': {'label': 'Approved', 'value': None},
#     'assoc_cl_id': '40f23c73db7cb4104a0db1a5f396190f',
#     'assoc_code': 'C000004',
#     'credit_points': '240',
#     'assoc_title': 'Bachelor of Arts',
#     'short_title': 'C000004 - Bachelor of Arts'}],
#   'descriptions': [{'short_description': None,
#     'countries': [],
#     'linking_id': '2a42a9eedb1174104a0db1a5f3961968',
#     'applies_to_all_countries': 'true',
#     'long_description': '<p>Oil spills. The conflict in Syria. Euthanasia. Our right to privacy. The law plays an integral role in managing how each of these issues – and countless more across the globe – are analysed, evaluated and resolved.</p>\n<p>The hallmark of Macquarie’s Bachelor of Laws is its recognition of the way legal frameworks underpin such global issues. You’ll be challenged to think critically about the law to seek innovative solutions to legal problems – skills highly valued by employers. With the option to combine your law degree with any other Macquarie bachelor degree, you can open the way to an array of careers in legal practice, private industry, government, education and community services.</p>',
#     'keywords': [],
#     'description_type': {'value': 'Long Description', 'key': 'display_name'}},
#    {'short_description': '<p>Learn to think critically about the law, and seek innovative solutions to legal problems. Our law degree gives you practical and ethical skills employers value.</p>',
#     'countries': [],
#     'linking_id': '3142e9eedb1174104a0db1a5f396199e',
#     'applies_to_all_countries': 'true',
#     'long_description': None,
#     'keywords': [],
#     'description_type': {'value': 'Short Description',
#      'key': 'display_name'}}],
#   'entry_requirements': [],
#   'testimonials': [{'testimonial_theme': {'value': 'Global',
#      'key': 'display_name'},
#     'image_link': 'https://www.mq.edu.au/__data/assets/image/0008/1177964/fraser-lawrance.jpg',
#     'video_alt_text': '',
#     'countries': [],
#     'linking_id': '716421a2db5174104a0db1a5f3961930',
#     'testimonial_category': 'Career outcomes',
#     'area_of_study': {'value': 'Arts and social sciences',
#      'key': 'display_name'},
#     'testimonial_type': 'Testimonial text',
#     'keywords': [],
#     'image_alt_text': 'Fraser Lawrance',
#     'video_link': '',
#     'applies_to_all_countries': 'true',
#     'testimonial_reference': {'value': 'Fraser Lawrance',
#      'key': 'display_name'},
#     'author_title': 'Bachelor of Arts (International Relations) with Bachelor of Laws',
#     'name': 'Fraser Lawrance',
#     'author_name': 'Fraser Lawrance',
#     'description': 'Macquarie has challenged my way of thinking and helped me question my held ideas and why I think the way I do. My ambition is to become a diplomat, receive postings overseas where I can be involved in current world events, and hopefully make a positive impact.',
#     'testimonial_reference_cl_id': '461c498ddb45bc5046b0b5ec34961993',
#     'published': 'false'}],
#   'accreditations': [],
#   'classification_areas': [{'area_of_study': [{'area_of_study': {'value': 'Law',
#        'key': 'display_name'},
#       'keywords': [],
#       'linking_id': 'ebd06d6edb1174104a0db1a5f39619f7',
#       'area_of_interest': {'value': 'International law',
#        'key': 'display_name'},
#       'links': []},
#      {'area_of_study': {'value': 'Law', 'key': 'display_name'},
#       'keywords': [],
#       'linking_id': 'f6e0ad6edb1174104a0db1a5f39619d4',
#       'area_of_interest': {'value': 'Public policy and law',
#        'key': 'display_name'},
#       'links': []},
#      {'area_of_study': {'value': 'Law', 'key': 'display_name'},
#       'keywords': [],
#       'linking_id': '90c0a56edb1174104a0db1a5f39619d2',
#       'area_of_interest': {'value': 'Environmental law',
#        'key': 'display_name'},
#       'links': []},
#      {'area_of_study': {'value': 'Law', 'key': 'display_name'},
#       'keywords': [],
#       'linking_id': 'e180696edb1174104a0db1a5f396192c',
#       'area_of_interest': {'value': 'Commercial law', 'key': 'display_name'},
#       'links': []},
#      {'area_of_study': {'value': 'Law', 'key': 'display_name'},
#       'keywords': [],
#       'linking_id': '7ab0296edb1174104a0db1a5f3961977',
#       'area_of_interest': {'value': 'Criminal law', 'key': 'display_name'},
#       'links': []},
#      {'area_of_study': {'value': 'Law', 'key': 'display_name'},
#       'keywords': [],
#       'linking_id': 'f5c06d6edb1174104a0db1a5f39619ed',
#       'area_of_interest': {'value': 'Governance', 'key': 'display_name'},
#       'links': []},
#      {'area_of_study': {'value': 'Law', 'key': 'display_name'},
#       'keywords': [],
#       'linking_id': 'f8e0ad6edb1174104a0db1a5f39619c9',
#       'area_of_interest': {'value': 'Law and the media',
#        'key': 'display_name'},
#       'links': []},
#      {'area_of_study': {'value': 'Law', 'key': 'display_name'},
#       'keywords': [],
#       'linking_id': 'd7c06d6edb1174104a0db1a5f39619d9',
#       'area_of_interest': {'value': 'Human rights and social justice',
#        'key': 'display_name'},
#       'links': []}]}],
#   'links': []},
#  'relevant_prior_workexperience_professional_certification': [],
#  'external_provider': '',
#  'credit_points_header': '320 credit points',
#  'relevant_prior_qualifications_professional_certification': [],
#  'course_search_title': 'C000132 - Bachelor of Laws',
#  'availableDoubles': '',
#  'other_requirements': '',
#  'partner_org_unit_data': [[]],
#  'links': [],
#  'academic_item_path': '/find-a-course/courses/bachelor-of-laws',
#  'majors_available': '',
#  'specialisations_available': '',
#  'isMajor': False,
#  'isSingle': True,
#  'isDouble': False,
#  'isPathway': False,
#  'isPopularDouble': False,
#  'isSpecialisation': False,
#  'isDynamicDouble': False,
#  'isPG': False,
#  'isVerticalDouble': False,
#  'isOfferedToInternational': True,
#  'isOfferedToDomestic': True,
#  'year': '2024'}

# %%
converted['curriculum_structure'][0]
# Out:
# {'ai_to_cs_cl_id': 'dc9ff57b9776fd9049533c4ef053af9e',
#  'curriculum_structure': {'value': '', 'key': 'version_code'},
#  'source': {'value': '', 'key': ''},
#  'effective_date': '',
#  'credit_points': '320',
#  'structure_cl_id': 'fc8002fb9776fd9049533c4ef053af72',
#  'parent_table': 'x_f5sl_cl_courses',
#  'name': 'Structure',
#  'parent_id': {'value': 'Course: C000132',
#   'key': 'code',
#   'type': 'x_f5sl_cl_courses'},
#  'container': [{'child_table': '',
#    'footnote': '',
#    'map_type': '',
#    'parent_table': 'x_f5sl_cl_curriculum_structure',
#    'parent_connector': {'label': 'AND', 'value': 'AND'},
#    'description': 'You can use your flexible zone to enrol in any Undergraduate unit for which you meet the requisites. You may also use your flexible zone to complete a major or a minor(s).',
#    'credit_points': '80',
#    'horizontal_grouping': {'label': None, 'value': None},
#    'title': 'Flexible Zone',
#    'vertical_grouping': {'label': 'FLEXIBLE', 'value': 'flexible'},
#    'credit_points_max': '',
#    'parent_record': {'value': 'Curriculum Structure: ',
#     'key': 'version_code',
#     'type': 'x_f5sl_cl_curriculum_structure'},
#    'preface': '',
#    'dynamic_query': '',
#    'child_record': {'value': '', 'key': '', 'type': None},
#    'relationship': [],
#    'dynamic_relationship': [],
#    'container': [],
#    'order': '100'},
#   {'child_table': '',
#    'footnote': '',
#    'map_type': '',
#    'parent_table': 'x_f5sl_cl_curriculum_structure',
#    'parent_connector': {'label': 'AND', 'value': 'AND'},
#    'description': '',
#    'credit_points': '240',
#    'horizontal_grouping': {'label': None, 'value': None},
#    'title': 'Core Zone',
#    'vertical_grouping': {'label': 'CORE', 'value': 'core'},
#    'credit_points_max': '',
#    'parent_record': {'value': 'Curriculum Structure: ',
#     'key': 'version_code',
#     'type': 'x_f5sl_cl_curriculum_structure'},
#    'preface': '',
#    'dynamic_query': '',
#    'child_record': {'value': '', 'key': '', 'type': None},
#    'relationship': [],
#    'dynamic_relationship': [],
#    'container': [{'child_table': '',
#      'footnote': '',
#      'map_type': '',
#      'parent_table': 'x_f5sl_cl_cs_container',
#      'parent_connector': {'label': 'AND', 'value': 'AND'},
#      'description': 'Complete 10 credit points from the following PACE options.',
#      'credit_points': '10',
#      'horizontal_grouping': {'label': None, 'value': None},
#      'title': 'Elective units',
#      'vertical_grouping': {'label': 'ELECTIVE', 'value': 'elective'},
#      'credit_points_max': '',
#      'parent_record': {'value': 'Curriculum Structure Container: Core Zone',
#       'key': 'title',
#       'type': 'x_f5sl_cl_cs_container'},
#      'preface': '',
#      'dynamic_query': '',
#      'child_record': {'value': '', 'key': '', 'type': None},
#      'relationship': [{'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5078',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'PACE: Clinics and Projects',
#        'academic_item_code': 'LAWS5078',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5078',
#        'order': '100'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5051',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'PACE: Individual Placements',
#        'academic_item_code': 'LAWS5051',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5051',
#        'order': '0'}],
#      'dynamic_relationship': [],
#      'container': [],
#      'order': '200'},
#     {'child_table': '',
#      'footnote': '',
#      'map_type': '',
#      'parent_table': 'x_f5sl_cl_cs_container',
#      'parent_connector': {'label': 'AND', 'value': 'AND'},
#      'description': 'Complete the capstone unit below.',
#      'credit_points': '10',
#      'horizontal_grouping': {'label': None, 'value': None},
#      'title': 'Capstone unit',
#      'vertical_grouping': {'label': 'CAPSTONE', 'value': 'capstone'},
#      'credit_points_max': '',
#      'parent_record': {'value': 'Curriculum Structure Container: Core Zone',
#       'key': 'title',
#       'type': 'x_f5sl_cl_cs_container'},
#      'preface': '',
#      'dynamic_query': '',
#      'child_record': {'value': '', 'key': '', 'type': None},
#      'relationship': [{'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Capstone unit',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5000',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Remedies, Reparations and Resolution in Law',
#        'academic_item_code': 'LAWS5000',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5000',
#        'order': '0'}],
#      'dynamic_relationship': [],
#      'container': [],
#      'order': '100'},
#     {'child_table': '',
#      'footnote': '',
#      'map_type': '',
#      'parent_table': 'x_f5sl_cl_cs_container',
#      'parent_connector': {'label': 'AND', 'value': 'AND'},
#      'description': 'Complete 80 credit points from the following options.',
#      'credit_points': '80',
#      'horizontal_grouping': {'label': None, 'value': None},
#      'title': 'Elective units',
#      'vertical_grouping': {'label': 'ELECTIVE', 'value': 'elective'},
#      'credit_points_max': '',
#      'parent_record': {'value': 'Curriculum Structure Container: Core Zone',
#       'key': 'title',
#       'type': 'x_f5sl_cl_cs_container'},
#      'preface': '',
#      'dynamic_query': '',
#      'child_record': {'value': '', 'key': '', 'type': None},
#      'relationship': [{'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5056',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Succession',
#        'academic_item_code': 'LAWS5056',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5056',
#        'order': '1800'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5018',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Indigenous Peoples and the Law',
#        'academic_item_code': 'LAWS5018',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5018',
#        'order': '500'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5020',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Family Law',
#        'academic_item_code': 'LAWS5020',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5020',
#        'order': '700'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5065',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Dispute Management and Resolution',
#        'academic_item_code': 'LAWS5065',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5065',
#        'order': '2100'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5030',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Law Moots and Competitions',
#        'academic_item_code': 'LAWS5030',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5030',
#        'order': '1200'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5069',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Energy and Natural Resources Law',
#        'academic_item_code': 'LAWS5069',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5069',
#        'order': '2200'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5087',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Law of Armed Conflict',
#        'academic_item_code': 'LAWS5087',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5087',
#        'order': '2900'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5053',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Taxation',
#        'academic_item_code': 'LAWS5053',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5053',
#        'order': '1700'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5071',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Health Law and Ethics',
#        'academic_item_code': 'LAWS5071',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5071',
#        'order': '2300'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5910',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Research Methodologies in Law',
#        'academic_item_code': 'LAWS5910',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5910',
#        'order': '3400'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5043',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Climate Change Law',
#        'academic_item_code': 'LAWS5043',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5043',
#        'order': '1500'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5036',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Modern Corporate Governance',
#        'academic_item_code': 'LAWS5036',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5036',
#        'order': '1300'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5082',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Insolvency Law',
#        'academic_item_code': 'LAWS5082',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5082',
#        'order': '2600'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5010',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'International Trade Law',
#        'academic_item_code': 'LAWS5010',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5010',
#        'order': '200'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5021',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Foundations of Commercial Law',
#        'academic_item_code': 'LAWS5021',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5021',
#        'order': '800'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5920',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Legal Research Project',
#        'academic_item_code': 'LAWS5920',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5920',
#        'order': '3500'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5080',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Human Rights and Moral Dilemmas',
#        'academic_item_code': 'LAWS5080',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5080',
#        'order': '2500'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5028',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Competition Law',
#        'academic_item_code': 'LAWS5028',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5028',
#        'order': '1000'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5079',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Refugees and Migration',
#        'academic_item_code': 'LAWS5079',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5079',
#        'order': '2400'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5057',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'International Private Law',
#        'academic_item_code': 'LAWS5057',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5057',
#        'order': '1900'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5007',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Employment and Labour Law ',
#        'academic_item_code': 'LAWS5007',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5007',
#        'order': '100'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5302',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'International Law Exchange 2',
#        'academic_item_code': 'LAWS5302',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5302',
#        'order': '3100'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5040',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Environmental Planning Law',
#        'academic_item_code': 'LAWS5040',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5040',
#        'order': '1400'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5084',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Media Law',
#        'academic_item_code': 'LAWS5084',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5084',
#        'order': '2700'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5023',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Intellectual Property Law',
#        'academic_item_code': 'LAWS5023',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5023',
#        'order': '900'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5304',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'International Law Exchange 4',
#        'academic_item_code': 'LAWS5304',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5304',
#        'order': '3300'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5301',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'International Law Exchange 1',
#        'academic_item_code': 'LAWS5301',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5301',
#        'order': '3000'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5086',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Law of the Sea',
#        'academic_item_code': 'LAWS5086',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5086',
#        'order': '2800'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5060',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Environmental Law',
#        'academic_item_code': 'LAWS5060',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5060',
#        'order': '2000'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5005',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Age and the Law ',
#        'academic_item_code': 'LAWS5005',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5005',
#        'order': '0'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5012',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Banking and Finance Law ',
#        'academic_item_code': 'LAWS5012',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5012',
#        'order': '400'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5011',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Discrimination and the Law',
#        'academic_item_code': 'LAWS5011',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5011',
#        'order': '300'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5019',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'International Human Rights Law',
#        'academic_item_code': 'LAWS5019',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5019',
#        'order': '600'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5029',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Law and Technology',
#        'academic_item_code': 'LAWS5029',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5029',
#        'order': '1100'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5048',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Animal Law',
#        'academic_item_code': 'LAWS5048',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5048',
#        'order': '1600'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Elective units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS5303',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'International Law Exchange 3',
#        'academic_item_code': 'LAWS5303',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS5303',
#        'order': '3200'}],
#      'dynamic_relationship': [],
#      'container': [],
#      'order': '300'},
#     {'child_table': '',
#      'footnote': '',
#      'map_type': '',
#      'parent_table': 'x_f5sl_cl_cs_container',
#      'parent_connector': {'label': 'AND', 'value': 'AND'},
#      'description': 'Complete each unit below.',
#      'credit_points': '140',
#      'horizontal_grouping': {'label': None, 'value': None},
#      'title': 'Essential units',
#      'vertical_grouping': {'label': 'ESSENTIAL', 'value': 'essential'},
#      'credit_points_max': '',
#      'parent_record': {'value': 'Curriculum Structure Container: Core Zone',
#       'key': 'title',
#       'type': 'x_f5sl_cl_cs_container'},
#      'preface': '',
#      'dynamic_query': '',
#      'child_record': {'value': '', 'key': '', 'type': None},
#      'relationship': [{'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS1100',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Law, Lawyers and Society',
#        'academic_item_code': 'LAWS1100',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS1100',
#        'order': '100'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS2400',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Torts',
#        'academic_item_code': 'LAWS2400',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS2400',
#        'order': '800'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS3400',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Evidence',
#        'academic_item_code': 'LAWS3400',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS3400',
#        'order': '1300'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS3000',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Constitutional Law',
#        'academic_item_code': 'LAWS3000',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS3000',
#        'order': '1000'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS2000',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'International Law',
#        'academic_item_code': 'LAWS2000',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS2000',
#        'order': '400'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS2200',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Property Law',
#        'academic_item_code': 'LAWS2200',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS2200',
#        'order': '600'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS2100',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Jurisprudence',
#        'academic_item_code': 'LAWS2100',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS2100',
#        'order': '500'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS3200',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Civil and Criminal Procedure',
#        'academic_item_code': 'LAWS3200',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS3200',
#        'order': '1100'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS1300',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Criminal Justice',
#        'academic_item_code': 'LAWS1300',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS1300',
#        'order': '300'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS1000',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Foundations of Law',
#        'academic_item_code': 'LAWS1000',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS1000',
#        'order': '0'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS1200',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Contracts',
#        'academic_item_code': 'LAWS1200',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS1200',
#        'order': '200'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS3300',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Administrative Law',
#        'academic_item_code': 'LAWS3300',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS3300',
#        'order': '1200'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS2500',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.01R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Equity and Trusts',
#        'academic_item_code': 'LAWS2500',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS2500',
#        'order': '900'},
#       {'parent_connector': {'label': 'AND', 'value': 'AND'},
#        'credit_points': '',
#        'description': '',
#        'parent_record': {'value': 'Curriculum Structure Container: Essential units',
#         'key': 'title',
#         'type': 'x_f5sl_cl_cs_container'},
#        'owning_structure': {'value': '', 'key': 'version_code'},
#        'child_table': 'x_f5sl_cl_subjects',
#        'vertical_grouping': {'label': None, 'value': None},
#        'child_record': {'value': 'Unit: LAWS2300',
#         'key': 'code',
#         'type': 'x_f5sl_cl_subjects'},
#        'parent_table': 'x_f5sl_cl_cs_container',
#        'abbr_name': '',
#        'academic_item_version_name': '2024.02R',
#        'academic_item_type': 'subject',
#        'academic_item_name': 'Business Organisations',
#        'academic_item_code': 'LAWS2300',
#        'academic_item_credit_points': '10',
#        'abbreviated_name_and_major': None,
#        'academic_item_url': '/2024/units/LAWS2300',
#        'order': '700'}],
#      'dynamic_relationship': [],
#      'container': [],
#      'order': '0'}],
#    'order': '0'}]}

# %%
units = converted.get("curriculum_structure", [])[0].get("container", [])
for i in units[1]['container']:
    print(i['title'])
    print("------")
    for j in i['relationship']:
        print(j['academic_item_code'], j['academic_item_name'])
# Out:
# Elective units
# ------
# LAWS5078 PACE: Clinics and Projects
# LAWS5051 PACE: Individual Placements
# Capstone unit
# ------
# LAWS5000 Remedies, Reparations and Resolution in Law
# Elective units
# ------
# LAWS5056 Succession
# LAWS5018 Indigenous Peoples and the Law
# LAWS5020 Family Law
# LAWS5065 Dispute Management and Resolution
# LAWS5030 Law Moots and Competitions
# LAWS5069 Energy and Natural Resources Law
# LAWS5087 Law of Armed Conflict
# LAWS5053 Taxation
# LAWS5071 Health Law and Ethics
# LAWS5910 Research Methodologies in Law
# LAWS5043 Climate Change Law
# LAWS5036 Modern Corporate Governance
# LAWS5082 Insolvency Law
# LAWS5010 International Trade Law
# LAWS5021 Foundations of Commercial Law
# LAWS5920 Legal Research Project
# LAWS5080 Human Rights and Moral Dilemmas
# LAWS5028 Competition Law
# LAWS5079 Refugees and Migration
# LAWS5057 International Private Law
# LAWS5007 Employment and Labour Law
# LAWS5302 International Law Exchange 2
# LAWS5040 Environmental Planning Law
# LAWS5084 Media Law
# LAWS5023 Intellectual Property Law
# LAWS5304 International Law Exchange 4
# LAWS5301 International Law Exchange 1
# LAWS5086 Law of the Sea
# LAWS5060 Environmental Law
# LAWS5005 Age and the Law
# LAWS5012 Banking and Finance Law
# LAWS5011 Discrimination and the Law
# LAWS5019 International Human Rights Law
# LAWS5029 Law and Technology
# LAWS5048 Animal Law
# LAWS5303 International Law Exchange 3
# Essential units
# ------
# LAWS1100 Law, Lawyers and Society
# LAWS2400 Torts
# LAWS3400 Evidence
# LAWS3000 Constitutional Law
# LAWS2000 International Law
# LAWS2200 Property Law
# LAWS2100 Jurisprudence
# LAWS3200 Civil and Criminal Procedure
# LAWS1300 Criminal Justice
# LAWS1000 Foundations of Law
# LAWS1200 Contracts
# LAWS3300 Administrative Law
# LAWS2500 Equity and Trusts
# LAWS2300 Business Organisations
